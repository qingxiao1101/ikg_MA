# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# unzip files
import os
os.chdir("/content/drive/MyDrive/faster-rcnn-18.01.2021/data/self_dataset/")
# !ls
# !unzip composite_all.zip

# %%
#environment installation 
import os
os.chdir("/content/drive/MyDrive/faster-rcnn-18.01.2021/lib")
#!pip install -q torch==1.0.0 torchvision
# !pip install torchvision==0.5
# !pip install pillow==6.1
# !pip install scipy==1.1.0
# !pip install tensorboardX
# !python setup.py build develop

# %%
# train faster-rcnn
import os
os.chdir("/content/drive/MyDrive/faster-rcnn-18.01.2021/")
# !python trainval_net.py --net fpn50 --use_tfb --cag   --cuda --bs 1 --dataset composite_good   --epoch 20

# %%
# test faster-rcnn
#import os
#os.chdir("/content/drive/MyDrive/faster-rcnn-18.01.2021/")
#!python test.py --net fpn50 --use_tfb --cag   --cuda --bs 1 --dataset composite_mix   --epoch 20 #--use_pretrain_cnn

# %%
#evaluation based on complete image, rather than based on splited images. 
import os
os.chdir("/content/drive/MyDrive/faster-rcnn-18.01.2021/")
# !python draw_test_merged.py

# %%
# generate the pseudo labels for images in training dataset.
import os
os.chdir("/content/drive/MyDrive/faster-rcnn-18.01.2021/")
# !python run_train_image.py  --use_tfb --cag --net fpn50 --cuda --bs 1 --dataset composite_mix

# %%
# draw the detected boxes on complete training images
import os
os.chdir("/content/drive/MyDrive/faster-rcnn-18.01.2021/")
# !python draw_train_merged.py
